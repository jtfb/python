# %% [markdown]
# # Strings
# ## Practice Problems

# %% [markdown]
# ### 1. Write a multi-line string about anything you want and print it

# %%
word = "Hello"
name = "Tiago"
task = "homework"
f'{word}. I am printing a {name}\'s {task}'
# Out:
# "Hello. I am printing a Tiago's homework"

# %% [markdown]
# ### 2. Append a "world" to the following word.

# %%
word2 = "world"
new_word = " ".join([word, word2])
f'{new_word}. I am printing a {name}\'s {task}'
# Out:
# "Hello world. I am printing a Tiago's homework"
