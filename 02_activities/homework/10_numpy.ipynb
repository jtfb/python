# %% [markdown]
# # NumPy
# ## Practice Problems

# %% [markdown]
# ### 1. The formula for exponential growth is `population_size = N0 *e**rt`, where `N0` is the initial population, `e` is the exponential function, `r` is the rate, and `t` is time. Using this:
#
# 1.   Set the initial population, `N0`, as 100 and the growth rate, `r`, as 0.4
# 2.   Use the suitable `numpy` function to generate an array of time points, `t`, which go from 0 to 10 seconds, in 0.2 second increments.
# 3.   Write an expression to evaluate `population_size`, which should be an array of the population size for each time point in `t`.
# 4.   Create a new variable called `population_size_noise`, use the same expression you wrote in parts (3), and add noise to the population at each time point. Do this by adding an expression that uses a `numpy` function to generate a random value for each time point drawn from a normal distribution of `mean=0` and `stdev=250` (i.e., population_size_noise = expression_from_part_a + expression_to_add_noise).

# %%
import numpy as np

# set initial population
N0 = 100

# set growth rate
rate = 0.4

# Create an array of time points
t = np.arange(0, 10, 0.2)

# Create a population size
population_size = N0 * np.exp(rate * t)

#Create a noise
population_size_noise = population_size + np.random.normal(0, 250, np.shape(population_size))

print(population_size_noise)
# Out:
# [ 3.15447393e+02 -2.32846184e+02  1.94756102e+01  1.91251310e+02
#  -2.30940325e+00  4.81874921e+02  8.45970147e+01  9.45291663e+01
#   1.56143893e+01  9.47370089e+01  3.60178511e+01  1.45149560e+02
#   5.27879829e+02  6.51480927e+02  2.34984711e+02  1.24139019e+02
#   2.48604144e+02  4.32836242e+02  8.51485575e+01  4.57000888e+01
#   9.22431003e+01  3.45515828e+02  2.14124288e+02  7.12025083e+02
#   3.24652043e+02  6.55195061e+02  1.25591959e+02  7.17682011e+02
#   9.85715495e+02  1.17058679e+03  1.38189577e+03  1.17001950e+03
#   1.28447523e+03  1.15239402e+03  1.44319101e+03  1.76608348e+03
#   1.85128929e+03  2.18775766e+03  2.09637119e+03  2.29167820e+03
#   2.68674792e+03  2.53012964e+03  2.80822709e+03  2.84987165e+03
#   3.20655733e+03  3.77931475e+03  4.21847817e+03  4.68347575e+03
#   4.57522757e+03  5.12539028e+03]

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   ```python
#   import numpy as np
#
#   #set initial population
#   N0 = 100
#   #set growth rate
#   rate = 0.4
#   #create array of time points
#   t = np.arange(start=0, stop=10.2, step=0.2)
#
#   #calculate population of colony at the time points in t
#   population_size = N0 * np.exp(rate*t)
#   print('Population size is: ',population_size)
#
#   #add noise to population at each time point
#   population_size_noise = N0 * np.exp(rate*t) + np.random.normal(loc=0, scale=250, size=np.shape(population_size))
#   print('Population size with noise is: ',population_size_noise)
#   ```
# </details>

# %% [markdown]
# ### 2. Create a multiplication table for the number 6.

# %%
rows = np.arange(1,7)
columns = rows[:,np.newaxis]
arr = rows * columns

arr
# Out:
# array([[ 1,  2,  3,  4,  5,  6],
#        [ 2,  4,  6,  8, 10, 12],
#        [ 3,  6,  9, 12, 15, 18],
#        [ 4,  8, 12, 16, 20, 24],
#        [ 5, 10, 15, 20, 25, 30],
#        [ 6, 12, 18, 24, 30, 36]])

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   ```python
#   rows = np.arange(1, 7)
#   columns = rows[:,np.newaxis]
#   arr = rows * columns
#   arr
#   ```
# </details>

# %% [markdown]
# ### 3. Slice `arr` to create the following two arrays:
#
# `arr1` = [4, 12, 3]
#
# `arr2` = [3, 19]

# %%
# Creating an array
arr = np.array([[4, 12, 98], [12, 11, 92], [3, 19, 60]])
arr

# Slicing arr to get arr1
arr1 = arr[:, 0]
print(arr1)

# Slicing arr to get arr2
arr2 = arr[2, 0 : 2]
print(arr2)
# Out:
# [ 4 12  3]
# [ 3 19]

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   ```python
#   arr = np.array([[4, 12, 98], [12, 11, 92], [3, 19, 60]])
#   arr
#
#   arr1 = arr[:,0]
#   print(arr1)
#
#   arr2 = arr[2,0:2]
#   print(arr2)
#   ```
# </details>
